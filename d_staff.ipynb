# %%
import pandas as pd

# %%
d_staff_y=pd.read_csv('d_staff_y.csv')
d_staff_y
# Out:
#           id answered    enthusiastic_students                staff_trusted  \
# 0       a1-4        y    Somewhat enthusiastic          Trusted quite a bit
# 1       a1-6        y       Quite enthusiastic             Trusted somewhat
# 2       a1-7        y    Somewhat enthusiastic             Trusted somewhat
# 3      a1-10        y   Extremely enthusiastic             Trusted somewhat
# 4      a1-12        y       Quite enthusiastic  Trusted a tremendous amount
# ...      ...      ...                      ...                          ...
# 1750  m12-74        y   Extremely enthusiastic         Trusted a little bit
# 1751  m12-75        y    Slightly enthusiastic           Not at all trusted
# 1752  m12-78        y  Not at all enthusiastic  Trusted a tremendous amount
# 1753  m12-79        y  Not at all enthusiastic             Trusted somewhat
# 1754  m12-81        y    Somewhat enthusiastic  Trusted a tremendous amount
#
# ...

# %%
aonefilt = d_staff_y['id'].str.startswith['a1']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 aonefilt = d_staff_y['id'].str.startswith['a1']
#
# TypeError: 'method' object is not subscriptable

# %%
idtype = d_staff_y['id'].dtype
print(idtype)
# Out:
# object

# %%
d_staff_y['id']=d_staff_y['id'].astype(str)
print(d_staff_y['id'].dtype)
# Out:
# object

# %%
# Out:
# object
