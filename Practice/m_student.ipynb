# %%
import pandas as pd

# %%
m11_student=pd.read_csv('m11_student.csv')
m11_student
# Out:
#               id answered       respect_teacher          concerned_teacher  \
# 0      stu-m11-1        n                   NaN                        NaN
# 1      stu-m11-2        y  A few of my teachers       A few of my teachers
# 2      stu-m11-3        n                   NaN                        NaN
# 3      stu-m11-4        n                   NaN                        NaN
# 4      stu-m11-5        y   None of my teachers        None of my teachers
# ..           ...      ...                   ...                        ...
# 596  stu-m11-597        n                   NaN                        NaN
# 597  stu-m11-598        n                   NaN                        NaN
# 598  stu-m11-599        y    All of my teachers         All of my teachers
# 599  stu-m11-600        n                   NaN                        NaN
# 600  stu-m11-601        y    All of my teachers  About half of my teachers
#
#                 visit_teachers                how_teacher  \
# ...
