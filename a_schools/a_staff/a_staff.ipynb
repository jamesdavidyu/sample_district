# %%
import pandas as pd

# %%
a4_staff = pd.read_csv('a4_staff.csv')
a4_staff
# Out:
#        id answered    enthusiastic_students                staff_trusted  \
# 0    a4-1        n                      NaN                          NaN
# 1    a4-2        y    Slightly enthusiastic           Not at all trusted
# 2    a4-3        y  Not at all enthusiastic          Trusted quite a bit
# 3    a4-4        y       Quite enthusiastic           Not at all trusted
# 4    a4-5        n                      NaN                          NaN
# 5    a4-6        n                      NaN                          NaN
# 6    a4-7        y  Not at all enthusiastic  Trusted a tremendous amount
# 7    a4-8        n                      NaN                          NaN
# 8    a4-9        y  Not at all enthusiastic           Not at all trusted
# 9   a4-10        y    Slightly enthusiastic         Trusted a little bit
# 10  a4-11        n                      NaN                          NaN
# 11  a4-12        n                      NaN                          NaN
# ...

# %%
a4_staff_y = a4_staff['answered'].str('y')
a4_staff_y
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 a4_staff_y = a4_staff['answered'].str('y')
#       2 a4_staff_y
#
# TypeError: 'StringMethods' object is not callable

# %%
a4_staff
# Out:
#        id answered    enthusiastic_students                staff_trusted  \
# 0    a4-1        n                      NaN                          NaN
# 1    a4-2        y    Slightly enthusiastic           Not at all trusted
# 2    a4-3        y  Not at all enthusiastic          Trusted quite a bit
# 3    a4-4        y       Quite enthusiastic           Not at all trusted
# 4    a4-5        n                      NaN                          NaN
# 5    a4-6        n                      NaN                          NaN
# 6    a4-7        y  Not at all enthusiastic  Trusted a tremendous amount
# 7    a4-8        n                      NaN                          NaN
# 8    a4-9        y  Not at all enthusiastic           Not at all trusted
# 9   a4-10        y    Slightly enthusiastic         Trusted a little bit
# 10  a4-11        n                      NaN                          NaN
# 11  a4-12        n                      NaN                          NaN
# ...

# %%
print(a4_staff['answered'].dtype)
# Out:
# object

# %%
a4_staff['answered'] = a4_staff['answered'].astype(str)
print(a4_staff['answered'].dtype)
# Out:
# object
